# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghumandalaSinduja/Sentiment-Analysis/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LEXICON BASED APPROACH**

# %% [markdown]
# VADER SENTIMENT ANALYSIS

# %% [markdown]
# VADER stands for Valence Aware Dictionary and Sentiment Reasoner

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 6.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = 'The product is really awesome'
vs.polarity_scores(text)
# Out:
# {'compound': 0.659, 'neg': 0.0, 'neu': 0.477, 'pos': 0.523}

# %%
text2 = 'Batery is good .display is good charging takes 2 hours time camera photos come good but camera videos are not so good except camera video quality all are good I buy this phone for my dad'
vs.polarity_scores(text2)
# Out:
# {'compound': 0.5657, 'neg': 0.09, 'neu': 0.693, 'pos': 0.217}

# %%
text3 = 'It hangs and lag alot i cannot explain'
vs.polarity_scores(text3)
# Out:
# {'compound': -0.34, 'neg': 0.255, 'neu': 0.745, 'pos': 0.0}

# %% [markdown]
# WEB SCRAPING THE DATA

# %%
#using requests and BeautifulSoup library
#requests library is for taking api from http
#after  webscraping data will be in .csv form
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
#scraping only html content part

url = 'https://inshorts.com/en/read/sports'
news_data = []
news_category = url.split('/')[-1]
print(news_category)
data = requests.get(url)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# sports
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read sports news in English in less that 60 words and get updated with latest cricket, football, tennis and basketball in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/sports" rel="canonical"/>
# <link href="https://inshorts.com/en/read/sports" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>Sports News: Cricket News, Football News &amp; Tennis News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Mix panel script start -->
# <script>
#   (function(f,b){if(!b.__SV){var e,g,i,h;window.mixpanel=b;b._i=[];b.init=function(e,f,c){function g(a,d){var b=d.split(".");2==b.length&&(a=a[b[0]],d=b[1]);a[d]=function(){a.push([d].concat(Array.prototype.slice.call(arguments,0)))}}var a=b;"undefined"!==typeof c?a=b[c]=[]:c="mixpanel";a.people=a.people||[];a.toString=function(a){var d="mixpanel";"mixpanel"!==c&&(d+="."+c);a||(d+=" (stub)");return d};a.people.toString=function(){return a.toString(1)+".people (stub)"};i="disable time_event track track_pageview track_links track_forms track_with_groups add_group set_group remove_group register register_once alias unregister identify name_tag set_config reset opt_in_tracking opt_out_tracking has_opted_in_tracking has_opted_out_tracking clear_opt_in_out_tracking start_batch_senders people.set people.set_once people.unset people.increment people.append people.union people.track_charge people.clear_charges people.delete_user people.remove".split(" ");
#   for(h=0;h<i.length;h++)g(a,i[h]);var j="set set_once union unset remove delete".split(" ");a.get_group=function(){function b(c){d[c]=function(){call2_args=arguments;call2=[c].concat(Array.prototype.slice.call(call2_args,0));a.push([e,call2])}}for(var d={},e=["get_group"].concat(Array.prototype.slice.call(arguments,0)),c=0;c<j.length;c++)b(j[c]);return d};b._i.push([e,f,c])};b.__SV=1.2;e=f.createElement("script");e.type="text/javascript";e.async=!0;e.src="undefined"!==typeof MIXPANEL_CUSTOM_LIB_URL?
#   MIXPANEL_CUSTOM_LIB_URL:"file:"===f.location.protocol&&"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//)?"https://cdn.mxpnl.com/libs/mixpanel-2-latest.min.js":"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js";g=f.getElementsByTagName("script")[0];g.parentNode.insertBefore(e,g)}})(document,window.mixpanel||[]);
#   mixpanel.init("a99a1037068944b00a0cc8ee56c94e8c")
#   mixpanel.track("pageview")
#   </script>
# <!-- Mix panel script end -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <!-- Add After importing GA and Mixpanel scripts -->
# <script>
#   function track_GA_Mixpanel({hitType, category, action, label, value = 1}){
#     if (window && window.ga) {
#       ga('send', {
#             hitType: 'event',
#             eventCategory: category,
#             eventAction: action,
#             eventLabel: label,
#             eventValue: value
#         });
#     }
#     // mix panel analytics
#     if(window && window.mixpanel){
#         mixpanel.track("event", {category, action, label, value});
#     }
#   }
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/sports"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/sports"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToAllNews', 'action': 'clicked', 'label': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToIndiaNews', 'action': 'clicked', 'label': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToBusinessNews', 'action': 'clicked', 'label':  'RedirectedToBusinessNews' });"> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTosportsNews', 'action': 'clicked', 'label': 'RedirectedToSportsNews' });"> <li class="active-category selected">Sports</li> </a>
# <a href="/en/read/world" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToworldNews', 'action': 'clicked', 'label': 'RedirectedToworldNews' });"> <li class="active-category ">World</li> </a>
# <a href="/en/read/politics" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToworldNews', 'action': 'clicked',   'label': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTotechnologyNews', 'action': 'clicked', 'label': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTostartupNews', 'action': 'clicked', 'label': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToEntertainmentNews', 'action': 'clicked', 'label': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToMiscellaneousNews', 'action': 'clicked', 'label': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTohatkeNews', 'action': 'clicked', 'label': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToscienceNews', 'action': 'clicked', 'label': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToautomobileNews', 'action': 'clicked', 'label': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/i-got-chucked-out-of-india-t20i-squad-because-2019-world-cup-didnt-go-well-karthik-1622911533989" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="I got chucked out of India T20I squad because 2019 World Cup didn't go well: Karthik" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/5_sat/img_1622897171347_822.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/5_sat/img_1622897171347_822.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/i-got-chucked-out-of-india-t20i-squad-because-2019-world-cup-didnt-go-well-karthik-1622911533989" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'I%20got%20chucked%20out%20of%20India%20T20I%20squad%20because%202019%20World%20Cup%20didn't%20go%20well%3A%20Karthik)' });" style="color:#44444d!important">
# <span itemprop="headline">I got chucked out of India T20I squad because 2019 World Cup didn't go well: Karthik</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/i-got-chucked-out-of-india-t20i-squad-because-2019-world-cup-didnt-go-well-karthik-1622911533989"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-06-05T16:45:33.000Z" itemprop="datePublished">10:15 pm</span> on <span clas="date">05 Jun 2021,Saturday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Wicketkeeper-batsman Dinesh Karthik has said that he got chucked out of Team India's T20I squad because 2019 World Cup did not go well. "I thought I had done phenomenally well for India in T20s up till [2019 World Cup]," he added. "My aim is to play for the country in the T20 World Cups," he further said.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/i-got-chucked-out-of-india-t20i-squad-because-2019-world-cup-didnt-go-well-karthik-1622911533989"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-06-05T16:45:33.000Z" itemprop="dateModified">10:15 pm</span> on <span class="date">05 Jun</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/because-the-2019-world-cup-didnt-go-well-i-got-chuckled-out-of-t20s-dinesh-karthik/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/tokyo-olympics-organisers-say-they-want-athletes-to-take-15l-free-condoms-back-home-1622912150078" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Arshiya Chopra" itemprop="name"></span>
# </span>
# <span content="Tokyo Olympics organisers say they want athletes to take 1.5L free condoms back home" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/5_sat/img_1
news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls = ['https://inshorts.com/en/read/sports',
        'https://inshorts.com/en/read/politics',
        'https://inshorts.com/en/read/technology']
def build_dataset(urls):
  news_data = []
  for url in urls:
    news_category = url.split('/')[-1]
    #print(news_category)
    data = requests.get(url)
    soup = BeautifulSoup(data.content)
    #print(soup)
  
    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                      'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                      'news_category':news_category}

                    for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),  soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)
     
  df= pd.DataFrame(news_data)
  df = df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df
# Out:
#                                         news_headline  ... news_category
# 0   Tokyo Olympics organisers say they want athlet...  ...        sports
# 1   I got chucked out of India T20I squad because ...  ...        sports
# 2   Serena, Medvedev, Zverev enter fourth round of...  ...        sports
# 3   Chelsea extend manager Tuchel's contract to 20...  ...        sports
# 4   Mohammad Shami is no. 1 bowler for an Indian T...  ...        sports
# 5   Senior Athletics Championships to be held from...  ...        sports
# 6   Will make efforts to sort out issues between A...  ...        sports
# 7   If we only look at on-field cricket, Robinson'...  ...        sports
# 8   2022 Winter Olympics chance to press China on ...  ...        sports
# 9   Like bride coming back without getting married...  ...        sports
# 10  Hard to look past Kohli among recent greats: L...  ...        sports
# 11  Man City's Pep Guardiola named Premier League ...  ...        sports
# 12  Boult joins NZ squad in London for WTC final v...  ...        sports
# 13  Djokovic enters 4th round of French Open for r...  ...        sports
# 14  Everyone is gutted: India goalkeeper Sandhu af...  ...        sports
# 15  Theoretically, NZ have advantage but India mig...  ...        sports
# 16  Milkha Singh is better and more stable than ye...  ...        sports
# 17  Rafael Nadal will win 15 French Open titles: E...  ...        sports
# 18  Getting ball to go both ways at Rashid’s pace ...  ...        sports
# 19  Not sure this Indian side can dominate like WI...  ...        sports
# 20  FIR filed against Suvendu Adhikari, brother fo...  ...      politics
# 21  Delhi govt ready to make advance payment for v...  ...      politics
# 22  Former Telangana Health Minister Eatala Rajend...  ...      politics
# 23  Centre stopped doorstep delivery of ration sch...  ...      politics
# 24  WB puts Mamata's image on vaccine certificates...  ...      politics
# 25  Dear BJP, why do you hate Delhi: AAP asks Cent...  ...      politics
# 26  Mamata's nephew Abhishek Banerjee named TMC's ...  ...      politics
# 27  Forming govt with Ajit Pawar was a mistake: Fo...  ...      politics
# 28  Centre should ensure one crore vaccinations a ...  ...      politics
# 29  Lust for power amid COVID-19 will lead to anar...  ...      politics
# 30  People in UP more distressed with BJP than COV...  ...      politics
# 31  Will urge Punjab Guv to dismiss state govt: Ba...  ...      politics
# 32  6 Pune Sena members join NCP, vote against Pan...  ...      politics
# 33  BJP gave me ₹2.5L to withdraw Kerala poll nomi...  ...      politics
# 34  BJP seeks probe into profiteering via vaccine ...  ...      politics
# 35  Open to alliances with parties excluding Congr...  ...      politics
# 36  Trouble, not double-engine govt: Lalu Yadav af...  ...      politics
# 37  Minorities in UP spent last 4 yrs amid torture...  ...      politics
# 38  AIADMK united against Sasikala's comeback atte...  ...      politics
# 39  BJP lost a sincere leader: HP CM on Narinder B...  ...      politics
# 40  Zerodha CEO shares pic of Twitter rejecting hi...  ...    technology
# 41  Twitter restores verified blue tick of RSS chi...  ...    technology
# 42  After VP Venkaiah Naidu, Twitter removes blue ...  ...    technology
# 43  Twitter restores blue tick on VP Naidu's perso...  ...    technology
# 44  US can't take this abuse anymore: Trump after ...  ...    technology
# 45  Govt gives 'one last notice' to Twitter to imm...  ...    technology
# 46  China blocks candle, cake emojis on Weibo as p...  ...    technology
# 47  WhatsApp launches new feature to speed up voic...  ...    technology
# 48  Man harming self on live video saved after Fac...  ...    technology
# 49  Twitter 'indefinitely' suspended in Nigeria af...  ...    technology
# 50  Facebook suspends Donald Trump's account for 2...  ...    technology
# 51  HDFC Bank retracts crypto warning after RBI sa...  ...    technology
# 52  Twitter removes blue tick from VP Venkaiah Nai...  ...    technology
# 53  Music director Ghibran auctions unreleased 'Sa...  ...    technology
# 54  Alethea AI to launch Sotheby's auction of 'fir...  ...    technology
# 55  Apple working on iPad Pro with wireless chargi...  ...    technology
# 56  Antivirus software Norton 360 lets users mine ...  ...    technology
# 57  Designer makes robotic forehead eyeball 'Third...  ...    technology
# 58  Crypto must be important if Musk is interested...  ...    technology
# 59  Tesla's China vehicle orders fall by nearly ha...  ...    technology
#
# [60 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/RaghumandalaSinduja/news--sentiment/main/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   Serena's husband shares pics of her French Ope...  ...        sports
# 1   Ben Stokes trolls his England teammates over p...  ...        sports
# 2   Osaka withdraws from French Open after media b...  ...        sports
# 3   Lewis Hamilton shares video of him flying on h...  ...        sports
# 4   I never claimed to be vegan: Kohli after fans ...  ...        sports
# 5   Men's Cricket World Cup expanded to 14 teams f...  ...        sports
# 6   Punjab Kings' Nicholas Pooran marries long-tim...  ...        sports
# 7   Haven't seen anyone taking blows like that: Cu...  ...        sports
# 8   I haven't spoken to him yet: Babar Azam on Moh...  ...        sports
# 9   Either stop batter's advantage or stop making ...  ...        sports
# 10  Federer plays 1st Slam match after 487 days at...  ...        sports
# 11  Wish I could give her a hug: Serena on Osaka's...  ...        sports
# 12  Stuart Broad named England vice-captain for NZ...  ...        sports
# 13  England need to pick a playing XI that can win...  ...        sports
# 14  Players in their weak moments should be allowe...  ...        sports
# 15  COVID-19 affected Brazil confirmed as Copa Ame...  ...        sports
# 16  Sorry and sad for world no. 2 Osaka's withdraw...  ...        sports
# 17  De Bruyne doesn't need surgery, set to join Be...  ...        sports
# 18  As I sit injured, I'm blown away by Anderson's...  ...        sports
# 19  Sanjeet wins his 1st gold, 2nd for India at As...  ...        sports
# 20  Don't know how govt will vaccinate everybody b...  ...      politics
# 21  Congress leader Siddaramaiah admitted to Benga...  ...      politics
# 22  Govt says Mamata didn't take PM's permission t...  ...      politics
# 23  Delhi COVID-19 deaths/mn population 5 times mo...  ...      politics
# 24  Centre's vaccine procurement policy against fe...  ...      politics
# 25  BJP's Swapan Dasgupta, who lost WB polls, re-n...  ...      politics
# 26  Former MP Minister Laxmikant Sharma dies due t...  ...      politics
# 27  BMC polls to be held in Jan-Feb if COVID-19 un...  ...      politics
# 28  Stated the truth: Sidhu after Cong meet over r...  ...      politics
# 29  False narrative: WB Guv on Mamata's reasons fo...  ...      politics
# 30  Centre behaving like Hitler, Stalin: Mamata Ba...  ...      politics
# 31  Govt should clarify: Rahul seeks Centre's resp...  ...      politics
# 32  Old Parliament was not built for an independen...  ...      politics
# 33  Pawar may have advised Fadnavis on Opposition ...  ...      politics
# 34  BJP will see historic victory in 2022 Assembly...  ...      politics
# 35  Jharkhand unable to incur ₹1,100 cr for vaccin...  ...      politics
# 36  Ex-Bihar minister alleges scam in procurement ...  ...      politics
# 37  UP election candidate shot dead over political...  ...      politics
# 38  Notice to B'luru activist over BJP MLA's 'vacc...  ...      politics
# 39  37 BJP workers killed in Bengal after poll res...  ...      politics
# 40  How can one update COVID-19 vaccination status...  ...    technology
# 41  CoWIN doesn't collect data on people's COVID-1...  ...    technology
# 42  SAP adopts flexible working for its employees ...  ...    technology
# 43                LG stops making smartphones: Report  ...    technology
# 44  Samsung Publishing shares jump 10% after Musk ...  ...    technology
# 45  WhatsApp appoints Paresh B Lal as Grievance Of...  ...    technology
# 46   Google Photos' free unlimited storage ends today  ...    technology
# 47  Aarogya Setu to show blue shield for fully vac...  ...    technology
# 48  Poland starts trial against Huawei ex-exec ove...  ...    technology
# 49  Govt's child rights body accuses Twitter of vi...  ...    technology
# 50  Scammers use unsubscribe emails to confirm ema...  ...    technology
# 51  Centre proposes to exempt registration certifi...  ...    technology
# 52  Cryptos' regulation will happen: Sweden centra...  ...    technology
# 53  Tencent sued over 'inappropriate' content in H...  ...    technology
# 54  1% stake in Mexican football club Necaxa to be...  ...    technology
# 55  Coinbase allows users to use firm's card via A...  ...    technology
# 56  Sotheby's to sell 'first known NFT' in online ...  ...    technology
# 57  IIT Ropar makes temperature data logger for co...  ...    technology
# 58  Amazon planning to enter India's satellite bro...  ...    technology
# 59  Twitter working on 3 new misinformation warnin...  ...    technology
#
# [60 rows x 3 columns]

# %% [markdown]
# **PREPROCESSING**
#
# Cleaning the textual data

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
print(stopword_list)
print(len(stopword_list))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# 179

# %%
#removing two important stop words (no and not)

stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# 177

# %%
#remove html tags
def html_tag(text):
   soup = BeautifulSoup(text,"html.parser")
   new_text = soup.get_text()
   return new_text

html_tag('<html><h2> Some important information </h2></html>')
# Out:
# ' Some important information '

# %%
#expand contractions

# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("y'all can't expand I'd think")
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/11/4d/378ab91284c2c3a06ab475b287721c09b7951d5ecb3edf4ffb0e1e7a568a/contractions-0.0.49-py2.py3-none-any.whl
# Collecting textsearch>=0.0.21
#   Downloading https://files.pythonhosted.org/packages/d3/fe/021d7d76961b5ceb9f8d022c4138461d83beff36c3938dc424586085e559/textsearch-0.0.21-py2.py3-none-any.whl
# Collecting anyascii
#   Downloading https://files.pythonhosted.org/packages/a3/14/666cd44bf53f36a961544af592cb5c5c800013f9c51a4745af8d7c17362a/anyascii-0.2.0-py3-none-any.whl (283kB)
#      |████████████████████████████████| 286kB 5.2MB/s
# Collecting pyahocorasick
#   Downloading https://files.pythonhosted.org/packages/7f/c2/eae730037ae1cbbfaa229d27030d1d5e34a1e41114b21447d1202ae9c220/pyahocorasick-1.4.2.tar.gz (321kB)
#      |████████████████████████████████| 327kB 31.6MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.2-cp37-cp37m-linux_x86_64.whl size=85400 sha256=21d6943a8d2634c154ded82cd890e4417c01de54d0c733b9d1e03edfc79fee85
#   Stored in directory: /root/.cache/pip/wheels/3a/03/34/77e3ece0bba8b86bfac88a79f923b36d805cad63caeba38842
# Successfully built pyahocorasick
# Installing collected packages: anyascii, pyahocorasick, textsearch, contractions
# Successfully installed anyascii-0.2.0 contractions-0.0.49 pyahocorasick-1.4.2 textsearch-0.0.21
# 'you all can not expand I would think'

# %%
#removing special characters

import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text = re.sub(pattern,'',text)
  return text

print(remove_sp("Well this was fun! What do you think? 123#"))
print(remove_sp("@#$abc"))
# Out:
# Well this was fun What do you think 123
# abc

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
#removing stop words
# Tokenization -  splitting a sentence into list

def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)    #considering tokens
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]       # checking whether it is in stopwords_list or not if there removing from stopwords_list
  filtered_text = ' '.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords(" The, and, if are all stopwords and even not")
# Out:
# 'The , , stopwords even not'

# %%
# REMOVING
#1. Lower Case
#2. HTML tags
#3. Contractions
#4. Special characters
#5. stop words

# %%
df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())


df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)
df
# Out:
#                                         news_headline  ... news_category
# 0   serenas husband shares pics french open shoes ...  ...        sports
# 1   ben stokes trolls england teammates photoshoot...  ...        sports
# 2   osaka withdraws french open media boycott reve...  ...        sports
# 3   lewis hamilton shares video flying back 1st ti...  ...        sports
# 4      never claimed vegan kohli fans troll eggs diet  ...        sports
# 5   mens cricket world cup expanded 14 teams 2027 ...  ...        sports
# 6   punjab kings nicholas pooran marries longtime ...  ...        sports
# 7   not seen anyone taking blows like cummins puja...  ...        sports
# 8   not spoken yet babar azam mohammad amirs retir...  ...        sports
# 9   either stop batters advantage stop making cont...  ...        sports
# 10  federer plays 1st slam match 487 days french o...  ...        sports
# 11  wish could give hug serena osakas mental healt...  ...        sports
# 12    stuart broad named england vicecaptain nz tests  ...        sports
# 13  england need pick playing xi win vaughan nz tests  ...        sports
# 14      players weak moments allowed avoid media kaif  ...        sports
# 15  covid19 affected brazil confirmed copa america...  ...        sports
# 16  sorry sad world no 2 osakas withdrawal fft pre...  ...        sports
# 17  de bruyne not need surgery set join belgium eu...  ...        sports
# 18  sit injured I blown away andersons ability pla...  ...        sports
# 19  sanjeet wins 1st gold 2nd india asian boxing c...  ...        sports
# 20  not know govt vaccinate everybody december tha...  ...      politics
# 21  congress leader siddaramaiah admitted bengalur...  ...      politics
# 22  govt says mamata not take pms permission skip ...  ...      politics
# 23  delhi covid19 deathsmn population 5 times nati...  ...      politics
# 24  centres vaccine procurement policy federalism ...  ...      politics
# 25  bjps swapan dasgupta lost wb polls renominated...  ...      politics
# 26  former mp minister laxmikant sharma dies due c...  ...      politics
# 27        bmc polls held janfeb covid19 control mayor  ...      politics
# 28        stated truth sidhu cong meet rift punjab cm  ...      politics
# 29  false narrative wb guv mamatas reasons skippin...  ...      politics
# 30  centre behaving like hitler stalin mamata bane...  ...      politics
# 31  govt clarify rahul seeks centres response blac...  ...      politics
# 32  old parliament not built independent country puri  ...      politics
# 33  pawar may advised fadnavis opposition leaders ...  ...      politics
# 34  bjp see historic victory 2022 assembly polls d...  ...      politics
# 35  jharkhand unable incur 1100 cr vaccination hem...  ...      politics
# 36  exbihar minister alleges scam procurement ambu...  ...      politics
# 37  election candidate shot dead political enmity ...  ...      politics
# 38  notice bluru activist bjp mlas vaccine trade a...  ...      politics
# 39  37 bjp workers killed bengal poll results dili...  ...      politics
# 40  one update covid19 vaccination status new feat...  ...    technology
# 41  cowin not collect data peoples covid19 history...  ...    technology
# 42    sap adopts flexible working employees worldwide  ...    technology
# 43                 lg stops making smartphones report  ...    technology
# 44  samsung publishing shares jump 10 musk tweets ...  ...    technology
# 45  whatsapp appoints paresh b lal grievance offic...  ...    technology
# 46    google photos free unlimited storage ends today  ...    technology
# 47  aarogya setu show blue shield fully vaccinated...  ...    technology
# 48     poland starts trial huawei exexec spying china  ...    technology
# 49  govts child rights body accuses twitter violat...  ...    technology
# 50  scammers use unsubscribe emails confirm email ...  ...    technology
# 51  centre proposes exempt registration certificat...  ...    technology
# 52  cryptos regulation happen sweden central bank ...  ...    technology
# 53  tencent sued inappropriate content honor kings...  ...    technology
# 54  1 stake mexican football club necaxa auctioned...  ...    technology
# 55  coinbase allows users use firms card via apple...  ...    technology
# 56       sothebys sell first known nft online auction  ...    technology
# 57  iit ropar makes temperature data logger cold c...  ...    technology
# 58  amazon planning enter indias satellite broadba...  ...    technology
# 59  twitter working 3 new misinformation warning l...  ...    technology
#
# [60 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])
df
# Out:
#                                         news_headline  ... compound
# 0   serenas husband shares pics french open shoes ...  ...   0.8590
# 1   ben stokes trolls england teammates photoshoot...  ...   0.6369
# 2   osaka withdraws french open media boycott reve...  ...  -0.0000
# 3   lewis hamilton shares video flying back 1st ti...  ...   0.7269
# 4      never claimed vegan kohli fans troll eggs diet  ...   0.0772
# 5   mens cricket world cup expanded 14 teams 2027 ...  ...   0.6204
# 6   punjab kings nicholas pooran marries longtime ...  ...   0.6467
# 7   not seen anyone taking blows like cummins puja...  ...   0.8481
# 8   not spoken yet babar azam mohammad amirs retir...  ...   0.6486
# 9   either stop batters advantage stop making cont...  ...  -0.3000
# 10  federer plays 1st slam match 487 days french o...  ...  -0.4939
# 11  wish could give hug serena osakas mental healt...  ...   0.7579
# 12    stuart broad named england vicecaptain nz tests  ...  -0.1531
# 13  england need pick playing xi win vaughan nz tests  ...   0.7184
# 14      players weak moments allowed avoid media kaif  ...  -0.3818
# 15  covid19 affected brazil confirmed copa america...  ...  -0.4019
# 16  sorry sad world no 2 osakas withdrawal fft pre...  ...   0.2263
# 17  de bruyne not need surgery set join belgium eu...  ...   0.6846
# 18  sit injured I blown away andersons ability pla...  ...  -0.4333
# 19  sanjeet wins 1st gold 2nd india asian boxing c...  ...   0.8271
# 20  not know govt vaccinate everybody december tha...  ...  -0.3182
# 21  congress leader siddaramaiah admitted bengalur...  ...  -0.5106
# 22  govt says mamata not take pms permission skip ...  ...  -0.3182
# 23  delhi covid19 deathsmn population 5 times nati...  ...   0.0772
# 24  centres vaccine procurement policy federalism ...  ...   0.0000
# 25  bjps swapan dasgupta lost wb polls renominated...  ...  -0.6486
# 26  former mp minister laxmikant sharma dies due c...  ...   0.5719
# 27        bmc polls held janfeb covid19 control mayor  ...  -0.5267
# 28        stated truth sidhu cong meet rift punjab cm  ...   0.6124
# 29  false narrative wb guv mamatas reasons skippin...  ...  -0.2732
# 30  centre behaving like hitler stalin mamata bane...  ...  -0.4019
# 31  govt clarify rahul seeks centres response blac...  ...   0.1027
# 32  old parliament not built independent country puri  ...   0.2023
# 33  pawar may advised fadnavis opposition leaders ...  ...   0.2500
# 34  bjp see historic victory 2022 assembly polls d...  ...   0.7184
# 35  jharkhand unable incur 1100 cr vaccination hem...  ...   0.6369
# 36  exbihar minister alleges scam procurement ambu...  ...  -0.7579
# 37  election candidate shot dead political enmity ...  ...  -0.8555
# 38  notice bluru activist bjp mlas vaccine trade a...  ...  -0.5267
# 39  37 bjp workers killed bengal poll results dili...  ...  -0.6705
# 40  one update covid19 vaccination status new feat...  ...   0.0000
# 41  cowin not collect data peoples covid19 history...  ...   0.0000
# 42    sap adopts flexible working employees worldwide  ...   0.6369
# 43                 lg stops making smartphones report  ...  -0.2960
# 44  samsung publishing shares jump 10 musk tweets ...  ...   0.1779
# 45  whatsapp appoints paresh b lal grievance offic...  ...  -0.4588
# 46    google photos free unlimited storage ends today  ...   0.8271
# 47  aarogya setu show blue shield fully vaccinated...  ...   0.0000
# 48     poland starts trial huawei exexec spying china  ...  -0.4588
# 49  govts child rights body accuses twitter violat...  ...  -0.8558
# 50  scammers use unsubscribe emails confirm email ...  ...  -0.2023
# 51  centre proposes exempt registration certificat...  ...   0.3612
# 52  cryptos regulation happen sweden central bank ...  ...   0.8360
# 53  tencent sued inappropriate content honor kings...  ...   0.5423
# 54  1 stake mexican football club necaxa auctioned...  ...   0.8591
# 55  coinbase allows users use firms card via apple...  ...   0.4767
# 56       sothebys sell first known nft online auction  ...   0.2500
# 57  iit ropar makes temperature data logger cold c...  ...   0.3818
# 58  amazon planning enter indias satellite broadba...  ...   0.6705
# 59  twitter working 3 new misinformation warning l...  ...  -0.7506
#
# [60 rows x 4 columns]

# %%
df.iloc[0][0]
# Out:
# 'serenas husband shares pics french open shoes filled messages'

# %%
a = vs.polarity_scores(df.iloc[0][1])
a
# Out:
# {'compound': 0.859, 'neg': 0.052, 'neu': 0.684, 'pos': 0.264}

# %%
a['compound']
# Out:
# 0.859

# %%
a['neg']
# Out:
# 0.052

# %%
a['pos']
# Out:
# 0.264

# %%
df.shape[0]  #no.of rows
# Out:
# 60

# %%
score_neu=[]
score_pos = []
score_neg = []
for i in range(0,df.shape[0]):
  score = vs.polarity_scores(df.iloc[i][1])
  score1 = score['neu']
  score_neu.append(score1)
  score2 = score['pos']
  score_pos.append(score2)
  score3 = score['neg']
  score_neg.append(score3)

# %%
df["neutral-score"] = score_neu
df["positive-score"] = score_pos
df["negative-score"] = score_neg

# %%
df
# Out:
#                                         news_headline  ... negative-score
# 0   serenas husband shares pics french open shoes ...  ...          0.052
# 1   ben stokes trolls england teammates photoshoot...  ...          0.000
# 2   osaka withdraws french open media boycott reve...  ...          0.223
# 3   lewis hamilton shares video flying back 1st ti...  ...          0.074
# 4      never claimed vegan kohli fans troll eggs diet  ...          0.000
# 5   mens cricket world cup expanded 14 teams 2027 ...  ...          0.000
# 6   punjab kings nicholas pooran marries longtime ...  ...          0.102
# 7   not seen anyone taking blows like cummins puja...  ...          0.061
# 8   not spoken yet babar azam mohammad amirs retir...  ...          0.063
# 9   either stop batters advantage stop making cont...  ...          0.162
# 10  federer plays 1st slam match 487 days french o...  ...          0.155
# 11  wish could give hug serena osakas mental healt...  ...          0.000
# 12    stuart broad named england vicecaptain nz tests  ...          0.045
# 13  england need pick playing xi win vaughan nz tests  ...          0.050
# 14      players weak moments allowed avoid media kaif  ...          0.160
# 15  covid19 affected brazil confirmed copa america...  ...          0.129
# 16  sorry sad world no 2 osakas withdrawal fft pre...  ...          0.155
# 17  de bruyne not need surgery set join belgium eu...  ...          0.042
# 18  sit injured I blown away andersons ability pla...  ...          0.205
# 19  sanjeet wins 1st gold 2nd india asian boxing c...  ...          0.060
# 20  not know govt vaccinate everybody december tha...  ...          0.081
# 21  congress leader siddaramaiah admitted bengalur...  ...          0.105
# 22  govt says mamata not take pms permission skip ...  ...          0.057
# 23  delhi covid19 deathsmn population 5 times nati...  ...          0.047
# 24  centres vaccine procurement policy federalism ...  ...          0.000
# 25  bjps swapan dasgupta lost wb polls renominated...  ...          0.169
# 26  former mp minister laxmikant sharma dies due c...  ...          0.082
# 27        bmc polls held janfeb covid19 control mayor  ...          0.121
# 28        stated truth sidhu cong meet rift punjab cm  ...          0.000
# 29  false narrative wb guv mamatas reasons skippin...  ...          0.098
# 30  centre behaving like hitler stalin mamata bane...  ...          0.111
# 31  govt clarify rahul seeks centres response blac...  ...          0.053
# 32  old parliament not built independent country puri  ...          0.000
# 33  pawar may advised fadnavis opposition leaders ...  ...          0.044
# 34  bjp see historic victory 2022 assembly polls d...  ...          0.000
# 35  jharkhand unable incur 1100 cr vaccination hem...  ...          0.043
# 36  exbihar minister alleges scam procurement ambu...  ...          0.156
# 37  election candidate shot dead political enmity ...  ...          0.212
# 38  notice bluru activist bjp mlas vaccine trade a...  ...          0.112
# 39  37 bjp workers killed bengal poll results dili...  ...          0.120
# 40  one update covid19 vaccination status new feat...  ...          0.000
# 41  cowin not collect data peoples covid19 history...  ...          0.000
# 42    sap adopts flexible working employees worldwide  ...          0.000
# 43                 lg stops making smartphones report  ...          0.053
# 44  samsung publishing shares jump 10 musk tweets ...  ...          0.070
# 45  whatsapp appoints paresh b lal grievance offic...  ...          0.140
# 46    google photos free unlimited storage ends today  ...          0.044
# 47  aarogya setu show blue shield fully vaccinated...  ...          0.000
# 48     poland starts trial huawei exexec spying china  ...          0.100
# 49  govts child rights body accuses twitter violat...  ...          0.251
# 50  scammers use unsubscribe emails confirm email ...  ...          0.116
# 51  centre proposes exempt registration certificat...  ...          0.000
# 52  cryptos regulation happen sweden central bank ...  ...          0.000
# 53  tencent sued inappropriate content honor kings...  ...          0.038
# 54  1 stake mexican football club necaxa auctioned...  ...          0.000
# 55  coinbase allows users use firms card via apple...  ...          0.000
# 56       sothebys sell first known nft online auction  ...          0.000
# 57  iit ropar makes temperature data logger cold c...  ...          0.000
# 58  amazon planning enter indias satellite broadba...  ...          0.000
# 59  twitter working 3 new misinformation warning l...  ...          0.208
#
# [60 rows x 7 columns]

# %%
df.iloc[10][1]
# Out:
# 'world number eight roger federer defeated qualifier denis istomin 62 64 63 firstround french open monday 39yearold underwent two right knee surgeries last year playing fourth match 16 months federers first grand slam match since losing novak djokovic 487 days ago 2020 australian open semifinals'

# %%
#evaluate or predict the model for specific message

text=df['news_article'][41]
text
# Out:
# 'union health ministry monday said cowin platform not collect information covid19 infection history person cowin built platform manage vaccination country said cowin enforces rules relating gaps two shots announced centre time time added'

# %%
vs.polarity_scores(text)
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
vs.polarity_scores(df['news_article'][11])
# Out:
# {'compound': 0.7579, 'neg': 0.0, 'neu': 0.759, 'pos': 0.241}

# %%
text2 = 'the shoes i brought were amazing'
vs.polarity_scores(text2)
# Out:
# {'compound': 0.5859, 'neg': 0.0, 'neu': 0.568, 'pos': 0.432}

# %%
text1 = 'The mobile phone i bought was the worst and very bad'
vs.polarity_scores(text1)
# Out:
# {'compound': -0.8357, 'neg': 0.467, 'neu': 0.533, 'pos': 0.0}

# %% [markdown]
# **PREDICTION**

# %%
user_input = input("please enter your text")
#nltk.download("vader_lexicon")
vs = SentimentIntensityAnalyzer()
score = vs.polarity_scores(user_input)
if score==0:
  print(" ")
elif score["neg"]!=0:
   print('NEGATIVE and the score is:',score)
elif score["pos"]!=0:
   print("POSITIVE and the score is:",score)
elif score["neu"]!=0:
  print("NEUTRAL and the score is:",score)
# Out:
# please enter your texthey i am sinduja
# NEUTRAL and the score is: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %% [markdown]
# **DEPLOYMENT**

# %%
# !pip install streamlit --quiet
# !pip install pyngrok==4.1.1
from pyngrok import ngrok
# Out:
#      |████████████████████████████████| 8.2MB 5.0MB/s
#      |████████████████████████████████| 81kB 9.2MB/s
#      |████████████████████████████████| 4.2MB 26.8MB/s
#      |████████████████████████████████| 112kB 43.3MB/s
#      |████████████████████████████████| 174kB 42.4MB/s
#      |████████████████████████████████| 122kB 43.9MB/s
#      |████████████████████████████████| 71kB 7.7MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.5 which is incompatible.
# Collecting pyngrok==4.1.1
#   Downloading https://files.pythonhosted.org/packages/e4/a9/de2e15c92eb3aa4a2646ce3a7542317eb69ac47f667578ce8bf916320847/pyngrok-4.1.1.tar.gz
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyngrok==4.1.1) (0.16.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok==4.1.1) (3.13)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-cp37-none-any.whl size=15985 sha256=5c828315a7f5d48c559693a7aa8a7653e6f8dc5b532e514f2b363d2fad16401f
#   Stored in directory: /root/.cache/pip/wheels/97/71/0d/1695f7c8815c0beb3b5d9b35d6eec9243c87e6070fbe3977fa
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-4.1.1

# %%
# %%writefile app.py
import streamlit as st
import nltk
import joblib
from nltk.sentiment.vader import SentimentIntensityAnalyzer
st.title(' Sentiment analysis')
user_input = st.text_input("Please enter your text")
nltk.download("vader_lexicon")
vs = SentimentIntensityAnalyzer()
score = vs.polarity_scores(user_input)
st.button("Predict")
st.title("Result....")
if score==0:
   st.write(" ")
elif score["neg"]!=0:
   st.title('PREDICTED OUTPUT IS : NEGATIVE') 
   st.write('AND THE SCORE IS:', score)
elif score["pos"]!=0:
   st.title('PREDICTED OUTPUT IS: POSITIVE')
   st.write(' AND THE SCORE IS:', score)
elif score["neu"]!=0:
  st.title('PREDICTED OUTPUT IS : NEUTRAL')
  st.write(' AND THE SCORE IS:', score)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py &
url=ngrok.connect(port='8501')
url
# Out:
# nohup: appending output to 'nohup.out'
# 'http://49c0a0061a8a.ngrok.io'

# %%
import sys
sys.version
# Out:
# '3.7.10 (default, May  3 2021, 02:48:31) \n[GCC 7.5.0]'
